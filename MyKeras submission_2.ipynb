# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import keras_model as km
import keras_tools as tools
import utilities as ut
# Out:
# /home/sauttej/.local/share/virtualenvs/Whales-4YGaJ5HX/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
num_classes = 4250
config_dict = {'base_model': 'MobileNet', 
               'num_dense_layers': 3,
               'num_dense_units_0': 1024,
               'num_dense_units_1': 1024,
               'num_dense_units_2': 1024,
               'activation': 'relu',
               'dropout': False,
               'dropout_0': 1.0,
               'dropout_1': 0.5,
               'dropout_2': 1.0,
               'optimizer': "RMSProp",
               'learning_rate': 0.0001,    
               'cnn_learning_rate': 0.0001,               
               'cnn_unlock_epoch': 20,
               'unfreeze_percentage': 0.2,             
               'batch_size': 16}
model = km._create_pretrained_model(config_dict, num_classes = num_classes)
_, _, _, model = km.train(config_dict, epochs=40, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir="data/model_valid",
                valid_csv="data/model_valid.csv",
                save_model_path="model/180214_MobileNet_4250cl_40ep",  
                train_valid_split=.8,
                create_case = True)
# Out:
# training model MobileNet
# old directory removed data/model_train
# old directory removed data/model_valid
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# copy 22 images for whale # 6, called w_ab4cae2
# copy 22 images for whale # 7, called w_fd1cb9d
# copy 21 images for whale # 8, called w_43be268
# copy 21 images for whale # 9, called w_73d5489
# copy 21 images for whale # 10, called w_987a36f
# copy 20 images for whale # 11, called w_f19faeb
# copy 19 images for whale # 12, called w_95874a5
# copy 19 images for whale # 13, called w_9b401eb
# copy 18 images for whale # 14, called w_b7d5069
# copy 18 images for whale # 15, called w_c0d494d
# copy 17 images for whale # 16, called w_0e737d0
# copy 17 images for whale # 17, called w_18eee6e
# copy 17 images for whale # 18, called w_dbda0d6
# ...

# %%
config_dict['cnn_unlock_epoch']=0
config_dict['unfreeze_percentage']=0.2
_, _, _, model = km.train(config_dict, epochs=5, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir="data/model_valid",
                valid_csv="data/model_valid.csv",
                save_model_path="model/180214_MobileNet_4250cl_20_20_15ep_unfr02",  
                train_valid_split=.8,
                create_case = False)
# Out:
# training model MobileNet
# Found 6706 images belonging to 4250 classes.
# Found 4554 images belonging to 4250 classes.
#
#  ****** MobileNet unfrozen 5 top blocks, cut_off after layer 66 ******
# Epoch 1/5
#  - 107s - loss: 3.1598 - acc: 0.3101 - val_loss: 6.7151 - val_acc: 0.0704
# Epoch 2/5
#  - 105s - loss: 3.1460 - acc: 0.3264 - val_loss: 6.7671 - val_acc: 0.0722
# Epoch 3/5
#  - 109s - loss: 3.0924 - acc: 0.3297 - val_loss: 6.5805 - val_acc: 0.0776
# Epoch 4/5
#  - 109s - loss: 3.0527 - acc: 0.3358 - val_loss: 6.9380 - val_acc: 0.0599
# Epoch 5/5
#  - 106s - loss: 2.9856 - acc: 0.3495 - val_loss: 6.7009 - val_acc: 0.0783
# model saved:  model/180214_MobileNet_4250cl_20_20_15ep_unfr02

# %%
config_dict['cnn_unlock_epoch']=0
config_dict['unfreeze_percentage']=0.2
_, _, _, model = km.train(config_dict, epochs=5, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir="data/model_valid",
                valid_csv="data/model_valid.csv",
                save_model_path="model/180214_MobileNet_4250cl_20_20_20ep_unfr02",  
                train_valid_split=.8,
                create_case = False)
# Out:
# training model MobileNet
# Found 6706 images belonging to 4250 classes.
# Found 4554 images belonging to 4250 classes.
#
#  ****** MobileNet unfrozen 5 top blocks, cut_off after layer 66 ******
# Epoch 1/5
#  - 104s - loss: 2.9920 - acc: 0.3391 - val_loss: 6.7224 - val_acc: 0.0790
# Epoch 2/5
#  - 101s - loss: 2.9142 - acc: 0.3555 - val_loss: 6.7981 - val_acc: 0.0730
# Epoch 3/5
#  - 105s - loss: 2.9005 - acc: 0.3692 - val_loss: 6.7122 - val_acc: 0.0823
# Epoch 4/5
#  - 105s - loss: 2.8811 - acc: 0.3619 - val_loss: 6.6900 - val_acc: 0.0841
# Epoch 5/5
#  - 102s - loss: 2.8278 - acc: 0.3817 - val_loss: 6.7275 - val_acc: 0.0783
# model saved:  model/180214_MobileNet_4250cl_20_20_20ep_unfr02

# %%
config_dict['cnn_unlock_epoch']=0
config_dict['unfreeze_percentage']=0.2
_, _, _, model = km.train(config_dict, epochs=5, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir="data/model_valid",
                valid_csv="data/model_valid.csv",
                save_model_path="model/180214_MobileNet_4250cl_20_20_25ep_unfr02",  
                train_valid_split=.8,
                create_case = False)
# Out:
# training model MobileNet
# Found 6706 images belonging to 4250 classes.
# Found 4554 images belonging to 4250 classes.
#
#  ****** MobileNet unfrozen 5 top blocks, cut_off after layer 66 ******
# Epoch 1/5
#  - 106s - loss: 2.7976 - acc: 0.3816 - val_loss: 6.7223 - val_acc: 0.0811
# Epoch 2/5
#  - 104s - loss: 2.8035 - acc: 0.3816 - val_loss: 6.6471 - val_acc: 0.0876
# Epoch 3/5
#  - 102s - loss: 2.7495 - acc: 0.3895 - val_loss: 6.5459 - val_acc: 0.1008
# Epoch 4/5
#  - 106s - loss: 2.6958 - acc: 0.4029 - val_loss: 6.7294 - val_acc: 0.0888
# Epoch 5/5
#  - 105s - loss: 2.6493 - acc: 0.4087 - val_loss: 6.5434 - val_acc: 0.1045
# model saved:  model/180214_MobileNet_4250cl_20_20_25ep_unfr02

# %%
config_dict['cnn_unlock_epoch']=0
config_dict['unfreeze_percentage']=0.2
_, _, _, model = km.train(config_dict, epochs=5, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir="data/model_valid",
                valid_csv="data/model_valid.csv",
                save_model_path="model/180214_MobileNet_4250cl_20_20_30ep_unfr02",  
                train_valid_split=.8,
                create_case = False)
# Out:
# training model MobileNet
# Found 6706 images belonging to 4250 classes.
# Found 4554 images belonging to 4250 classes.
#
#  ****** MobileNet unfrozen 5 top blocks, cut_off after layer 66 ******
# Epoch 1/5
#  - 104s - loss: 2.6187 - acc: 0.4175 - val_loss: 6.5704 - val_acc: 0.1036
# Epoch 2/5
#  - 105s - loss: 2.6202 - acc: 0.4177 - val_loss: 6.5501 - val_acc: 0.0997
# Epoch 3/5
#  - 105s - loss: 2.5688 - acc: 0.4362 - val_loss: 6.6895 - val_acc: 0.0933
# Epoch 4/5
#  - 103s - loss: 2.5437 - acc: 0.4320 - val_loss: 6.5852 - val_acc: 0.0993
# Epoch 5/5
#  - 106s - loss: 2.5312 - acc: 0.4269 - val_loss: 6.6092 - val_acc: 0.0950
# model saved:  model/180214_MobileNet_4250cl_20_20_30ep_unfr02

# %%
config_dict['cnn_unlock_epoch']=0
config_dict['unfreeze_percentage']=0.4
_, _, _, model = km.train(config_dict, epochs=5, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir="data/model_valid",
                valid_csv="data/model_valid.csv",
                save_model_path="model/180214_MobileNet_4250cl_20_20_35ep_unfr04",  
                train_valid_split=.8,
                create_case = False)
# Out:
# training model MobileNet
# Found 6706 images belonging to 4250 classes.
# Found 4554 images belonging to 4250 classes.
#
#  ****** MobileNet unfrozen 10 top blocks, cut_off after layer 51 ******
# Epoch 1/5
#  - 107s - loss: 2.5154 - acc: 0.4351 - val_loss: 6.1819 - val_acc: 0.1545
# Epoch 2/5
#  - 104s - loss: 2.4747 - acc: 0.4357 - val_loss: 6.0476 - val_acc: 0.1568
# Epoch 3/5
#  - 105s - loss: 2.3959 - acc: 0.4573 - val_loss: 6.1452 - val_acc: 0.1596
# Epoch 4/5
#  - 103s - loss: 2.3145 - acc: 0.4702 - val_loss: 6.1291 - val_acc: 0.1589
# Epoch 5/5
#  - 107s - loss: 2.3304 - acc: 0.4745 - val_loss: 6.1599 - val_acc: 0.1560
# model saved:  model/180214_MobileNet_4250cl_20_20_35ep_unfr04

# %%
# retrain now using all data (no validation data left)
_, _, _, model = km.train(config_dict, epochs=10, model=model, num_classes=num_classes,
                save_data_path="plots",
                train_dir="data/model_train",    # copy data into this directory and train there
                train_csv="data/model_train.csv",    # copy data into this directory and train there
                valid_dir=None,
                valid_csv=None,
                save_model_path="model/180214_MobileNet_4250cl_40ep_retrain10_allin",  
                train_valid_split=1., # create new case without validation data
                create_case = True)   # create new case without validation data
# Out:
# training model MobileNet
# Found 176 images belonging to 7 classes.
#
#  ****** MobileNet unfrozen 10 top blocks, cut_off after layer 51 ******
# Epoch 1/10
#  - 2s - loss: 0.3207 - acc: 0.9148
# Epoch 2/10
#  - 2s - loss: 0.2391 - acc: 0.9318
# Epoch 3/10
#  - 2s - loss: 0.1939 - acc: 0.9545
# Epoch 4/10
#  - 2s - loss: 0.2442 - acc: 0.9091
# Epoch 5/10
#  - 2s - loss: 0.2951 - acc: 0.9148
# Epoch 6/10
#  - 2s - loss: 0.2459 - acc: 0.9375
# Epoch 7/10
#  - 2s - loss: 0.2515 - acc: 0.9375
# Epoch 8/10
#  - 2s - loss: 0.2147 - acc: 0.9375
# Epoch 9/10
#  - 2s - loss: 0.2369 - acc: 0.9318
# Epoch 10/10
#  - 2s - loss: 0.2304 - acc: 0.9545
# model saved:  model/180214_MobileNet_7cl_40ep_retrain10_allin

# %%
import keras
from keras.models import load_model
from keras.utils.generic_utils import CustomObjectScope
with CustomObjectScope({'relu6': keras.applications.mobilenet.relu6,'DepthwiseConv2D': keras.applications.mobilenet.DepthwiseConv2D}):
#     model = load_model('weights.hdf5')
    model = load_model("model/180214_MobileNet_7cl_40ep_retrain10")

# %%
'''
import numpy as np
ut.create_small_case(sel_whales = np.arange(1, num_classes+1),             # whales to be considered
      all_train_dir = "data/train",     # directory with original kaggle training data
      all_train_csv = "data/train.csv", # original kaggle train.csv file
      train_dir = "data/kaggle_train",   # training data actually used by model (subset of kaggle data) 
      train_csv = "data/kaggle_train.csv", # optional: write kaggle-like CSV File for actual training data
      valid_dir = None,   # optional: subdirectory with validation data
      valid_csv = None,     # optional: write kaggle-like CSV File for validation data
      train_valid = 1.,
      sub_dirs = False)
'''
# Out:
# old directory removed data/kaggle_train
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# copy 22 images for whale # 6, called w_ab4cae2
# copy 22 images for whale # 7, called w_fd1cb9d
# copy 21 images for whale # 8, called w_43be268
# copy 21 images for whale # 9, called w_73d5489
# copy 21 images for whale # 10, called w_987a36f
# copy 20 images for whale # 11, called w_f19faeb
# copy 19 images for whale # 12, called w_95874a5
# copy 19 images for whale # 13, called w_9b401eb
# copy 18 images for whale # 14, called w_b7d5069
# copy 18 images for whale # 15, called w_c0d494d
# copy 17 images for whale # 16, called w_0e737d0
# copy 17 images for whale # 17, called w_18eee6e
# copy 17 images for whale # 18, called w_dbda0d6
# copy 17 images for whale # 19, called w_eb0a6ed
# ...

# %%
file_names, model_preds, true_labels = tools.compute_preds(model, num_classes, train_dir = "data/model_train",
                                                           test_dir = "data/kaggle_test", test_csv = '')
# Out:
# training model MobileNet
# Found 15610 images belonging to 1 classes.
# 976/976 [==============================] - 194s 199ms/step
# fn Whales/test/00029b3a.jpg
# fn Whales/test/0003c693.jpg
# fn Whales/test/000bc353.jpg

# %%
print(model_preds[:3])
# Out:
# [['w_701972b', 'w_49a3b14', 'w_e613f12', 'w_0e0e856', 'w_f0af1f8'], ['w_d88328d', 'w_307065e', 'w_c027e4e', 'w_1c2fb13', 'w_0b775c1'], ['w_a5a13d0', 'w_8d83172', 'w_d89b29e', 'w_d2be6cc', 'w_e02fe7b']]

# %%
print(len(file_names))
print(file_names[:10])
# Out:
# 15610
# ['00029b3a.jpg', '0003c693.jpg', '000bc353.jpg', '0010a672.jpg', '00119c3f.jpg', '001259cc.jpg', '0015f9b4.jpg', '0018c4ba.jpg', '001bf484.jpg', '002d8d81.jpg']

# %%
tools.write_pred_to_csv(file_names,model_preds, path = "data/submission.csv")
# Out:
# write csv file
# done writing csv file

# %%
num_classes = 10
# run_2018-02-08-102722_

# run_2018-02-08-091830_/
gogo_config_dict = {'base_model': 'InceptionV3', 
               'num_dense_layers': 3,
               'num_dense_units_0': 1024,
               'num_dense_units_1': 1024,
               'num_dense_units_2': 500,
               'activation': 'relu',
               # 'dropout': False,
               # 'dropout_0': 1.0,
               # 'dropout_1': 1.0,
               # 'dropout_2': 1.0,
               'optimizer': "Adam",
               'learning_rate': 0.000855,
               'cnn_learning_rate': 0.0001239196656395728,               
               'cnn_unlock_epoch': 15,
               'unfreeze_percentage': 0.233,
               'batch_size': 16}


gaga_config_dict = {'base_model': 'InceptionV3', 
               'num_dense_layers': 3,
               'num_dense_units_0': 1024,
               'num_dense_units_1': 1024,
               'num_dense_units_2': 1024,
               'activation': 'relu',
               # 'dropout': False,
               # 'dropout_0': 1.0,
               # 'dropout_1': 1.0,
               # 'dropout_2': 1.0,
               'optimizer': "RMSProp",
               'learning_rate': 0.00023,
               'cnn_learning_rate': 0.00029,               
               'cnn_unlock_epoch': 27,
               'unfreeze_percentage': 0.25,
               'batch_size': 29}  

config_dict = {'base_model': 'InceptionV3', 
               'num_dense_layers': 2,
               'num_dense_units_0': 223,
               'num_dense_units_1': 292,
               # 'num_dense_units_2': 1024,
               # 'num_dense_units_3': 1024,               
               'activation': 'relu',
               'dropout': False,
               'dropout_0': 1.0,
               'dropout_1': 0.5,
               'dropout_2': 1.0,
               'dropout_3': 1.0,               
               'optimizer': "RMSProp",
               'learning_rate': 0.00023,
               'cnn_learning_rate': 0.00029,               
               'cnn_unlock_epoch': 27,
               'unfreeze_percentage': 0.25,
               'batch_size': 29}


model = km._create_pretrained_model(config_dict, num_classes)



'''
run_2018-02-08-102722_
{'learning_rate': 0.00023655094239998902, 'activation': 'relu', 
 'optimizer': 'RMSProp', 'cnn_learning_rate': 0.0002904734235037702, 'base_model': 'InceptionV3', 
 'batch_size': 29, 'cnn_unlock_epoch': 27, 'num_dense_units_0': 223, 
 'unfreeze_percentage': 0.25421300885137144, 'num_dense_units_1': 292, 'num_dense_layers': 2}


hyperband_2018-02-08-003439_testrun/run_2018-02-08-091830_/
{'activation': 'relu', 'optimizer': 'Adam', 'cnn_learning_rate': 0.0001239196656395728, 'base_model': 'InceptionV3', 
'batch_size': 16, 'num_dense_units_2': 168, 'unfreeze_percentage': 0.23322586787101596, 
'num_dense_units_1': 182, 'num_dense_units_0': 118, 'learning_rate': 0.0008553489861247746, 
'cnn_unlock_epoch': 15, 'num_dense_layers': 3} 
 
 
'''
# Out:
# "\nrun_2018-02-08-102722_\n{'learning_rate': 0.00023655094239998902, 'activation': 'relu', \n 'optimizer': 'RMSProp', 'cnn_learning_rate': 0.0002904734235037702, 'base_model': 'InceptionV3', \n 'batch_size': 29, 'cnn_unlock_epoch': 27, 'num_dense_units_0': 223, \n 'unfreeze_percentage': 0.25421300885137144, 'num_dense_units_1': 292, 'num_dense_layers': 2}\n\n\nhyperband_2018-02-08-003439_testrun/run_2018-02-08-091830_/\n{'activation': 'relu', 'optimizer': 'Adam', 'cnn_learning_rate': 0.0001239196656395728, 'base_model': 'InceptionV3', \n'batch_size': 16, 'num_dense_units_2': 168, 'unfreeze_percentage': 0.23322586787101596, \n'num_dense_units_1': 182, 'num_dense_units_0': 118, 'learning_rate': 0.0008553489861247746, \n'cnn_unlock_epoch': 15, 'num_dense_layers': 3} \n \n \n"

# %%
hist = km.train(config_dict, epochs=5, model=model, num_classes=num_classes)
# Out:
# training model InceptionV3
# old directory removed data/model_train
# old directory removed data/model_valid
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# copy 22 images for whale # 6, called w_ab4cae2
# copy 22 images for whale # 7, called w_fd1cb9d
# copy 21 images for whale # 8, called w_43be268
# copy 21 images for whale # 9, called w_73d5489
# copy 21 images for whale # 10, called w_987a36f
# 239  images of  10  whales copied in total
# Target Directory train:  data/model_train  validation:  data/model_valid
# 162  images copied as training data
# 77  images copied as validation data
# write csv file with training data: data/model_train.csv
# write csv file with validation data: data/model_valid.csv
# Found 162 images belonging to 10 classes.
# ...

# %%
tools.save_learning_curves(hist, "gaga", base_path="test_plots/")

# %%
num_classes_arr = [5,15,50,200,1000,4250]

results = km.eval_num_classes(num_classes_arr = num_classes_arr, base_model = 'MobileNet')
# Out:
# training model MobileNet
# old directory removed data/model_train
# old directory removed data/model_valid
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# 132  images of  5  whales copied in total
# Target Directory train:  data/model_train  validation:  data/model_valid
# 90  images copied as training data
# 42  images copied as validation data
# write csv file with training data: data/model_train.csv
# write csv file with validation data: data/model_valid.csv
# Found 90 images belonging to 5 classes.
# Found 42 images belonging to 5 classes.
# Epoch 1/20
#  - 4s - loss: 1.6648 - acc: 0.2976 - val_loss: 1.3586 - val_acc: 0.5952
# Epoch 2/20
#  - 1s - loss: 1.1764 - acc: 0.6076 - val_loss: 1.1847 - val_acc: 0.6667
# Epoch 3/20
# ...

# %%
accs = [0.7857,0.5933,0.4430,0.2671,0.1294,0.0199]
ut.save_plot_num_classes(results, num_classes_arr)

# %%
num_classes = 10
base_models = ['Dummy_model', 'InceptionV3', 'MobileNet', 'ResNet50', 'InceptionResNetV2']
# base_models = ['Dummy_model', 'InceptionV3']
results = km.eval_base_models(num_classes = num_classes, base_models = base_models)
print("results", results)
print("gaga", [result[0] for result in results])
# results = [(0.2,0.3), (0.1,0.4), (0.1,0.4), (0.1,0.4), (0.1,0.4)]
ut.save_bar_plot(results, base_models, num_classes)
# Out:
# MAP of Dummy Model averaged over 5 runs:  0.04600991325898389
# training model InceptionV3
# old directory removed data/model_train
# old directory removed data/model_valid
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# copy 22 images for whale # 6, called w_ab4cae2
# copy 22 images for whale # 7, called w_fd1cb9d
# copy 21 images for whale # 8, called w_43be268
# copy 21 images for whale # 9, called w_73d5489
# copy 21 images for whale # 10, called w_987a36f
# 239  images of  10  whales copied in total
# Target Directory train:  data/model_train  validation:  data/model_valid
# 162  images copied as training data
# 77  images copied as validation data
# write csv file with training data: data/model_train.csv
# write csv file with validation data: data/model_valid.csv
# ...

# %%
num_classes = 10
base_models = ['Dummy_model', 'InceptionV3', 'MobileNet', 'ResNet50', 'InceptionResNetV2']
results = km.eval_base_models(num_classes, base_models)

# %%
hist = 
save_learning_curves_2(history, cnn_after, run_name, base_path="plots/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7695bcbcc457> in <module>()
#       1 base_models = ['Dummy_model', 'InceptionV3', 'MobileNet', 'ResNet50', 'InceptionResNetV2']
#       2 results = [(0.2,0.3), (0.1,0.4), (0.1,0.4), (0.1,0.4), (0.1,0.4)]
# ----> 3 ut.save_bar_plot(results, base_models)
#
# NameError: name 'ut' is not defined

# %%
num_classes = 20
config_dict = {'base_model': 'MobileNet', 
               'num_dense_layers': 3,
               'num_dense_units_0': 1024,
               'num_dense_units_1': 1024,
               'num_dense_units_2': 1024,
               'activation': 'relu',
               'dropout': False,
               'dropout_0': 1.0,
               'dropout_1': 0.5,
               'dropout_2': 1.0,
               'optimizer': "RMSProp",
               'learning_rate': 0.0003,
               'cnn_learning_rate': 0.0001,               
               'cnn_unlock_epoch': 50,
               'unfreeze_percentage': 0.2,
               'batch_size': 16}
model = km._create_pretrained_model(config_dict, num_classes = num_classes)
hist = km.train(config_dict, epochs=70, model=model, num_classes=num_classes)
# Out:
# training model MobileNet
# old directory removed data/model_train
# old directory removed data/model_valid
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# copy 22 images for whale # 6, called w_ab4cae2
# copy 22 images for whale # 7, called w_fd1cb9d
# copy 21 images for whale # 8, called w_43be268
# copy 21 images for whale # 9, called w_73d5489
# copy 21 images for whale # 10, called w_987a36f
# copy 20 images for whale # 11, called w_f19faeb
# copy 19 images for whale # 12, called w_95874a5
# copy 19 images for whale # 13, called w_9b401eb
# copy 18 images for whale # 14, called w_b7d5069
# copy 18 images for whale # 15, called w_c0d494d
# copy 17 images for whale # 16, called w_0e737d0
# copy 17 images for whale # 17, called w_18eee6e
# copy 17 images for whale # 18, called w_dbda0d6
# ...

# %%
# print(hist[2])
tools.save_learning_curves_2(hist[2], 50, "unfreeze_layers", base_path="plots/poster_plots")

# %%
config_dict['cnn_unlock_epoch']=20
config_dict['unfreeze_percentage']=0.2
model = km._unfreeze_cnn_layers(model, config_dict)

# %%
# Out:
# created InceptionResNetV2
# successfuly created model:  InceptionResNetV2

# %%
tools.save_learning_curves(hist, "gaga", base_path="test_plots/")

# %%
tools.print_model_test_info(model, num_classes=5)
# Out:
# old directory removed data/model_test
# copy 34 images for whale # 1, called w_1287fbc
# copy 27 images for whale # 2, called w_98baff9
# copy 26 images for whale # 3, called w_7554f44
# copy 23 images for whale # 4, called w_1eafe46
# copy 22 images for whale # 5, called w_693c9ee
# copy 22 images for whale # 6, called w_ab4cae2
# copy 22 images for whale # 7, called w_fd1cb9d
# copy 21 images for whale # 8, called w_43be268
# copy 21 images for whale # 9, called w_73d5489
# copy 21 images for whale # 10, called w_987a36f
# 239  images of  10  whales copied in total
# Target Directory train:  data/model_test  validation:  None
# 239  images copied as training data
# 0  images copied as validation data
# write csv file with training data: data/model_test.csv
# Found 239 images belonging to 10 classes.
# 15/15 [==============================] - 268s 18s/step
# whale_class_map:
# ...
